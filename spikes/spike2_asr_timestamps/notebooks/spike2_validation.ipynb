# %%
from pathlib import Path

import pandas as pd

repo_root = (
    Path(__file__).resolve().parents[2] if "__file__" in globals() else Path.cwd().parents[2]
)
TRANSCRIPTS_DIR = repo_root / "data" / "transcripts"


episode_id = "0a639b5304954092a7b7771ba2c3d180"
parquet_file = TRANSCRIPTS_DIR / f"episode_id={episode_id}" / "part-00000.snappy.parquet"

df = pd.read_parquet(parquet_file)

print("Columns:", df.columns.tolist())
print("\nFirst 5 rows:")
display(df.head())

# Combine into a readable transcript preview
print("\nTranscript Preview:")
for _, row in df.head(10).iterrows():
    speaker = f"[{row.speaker}]" if "speaker" in df.columns and pd.notna(row.get("speaker")) else ""
    print(f"{speaker} ({row.start_ts:.1f}–{row.end_ts:.1f}s): {row.text}")

# Full text (joined)
full_text = " ".join(df["text"].astype(str).tolist())
print("\n--- FULL TEXT (first 1000 chars) ---")
print(full_text[:1000] + ("..." if len(full_text) > 1000 else ""))
# Out:
# Columns: ['segment_idx', 'start_ts', 'end_ts', 'text', 'asr_model', 'confidence']
#
# First 5 rows:
#    segment_idx  start_ts  end_ts  \
# 0            0       0.0  4213.0
#
#                                                 text   asr_model  confidence
# 0  Ladies and gentlemen, welcome back. I am joine...  assemblyai    0.971608
# Transcript Preview:
#  (0.0–4213.0s): Ladies and gentlemen, welcome back. I am joined by Robin Swan and Anthony Summers. You may recognize them from the most recent Netflix series on the disappearance of Madeleine McCann. Guys, welcome to the show. Thank you very much. So you are investigative journalists, but you're also married and you've been working together for about 30 years, is that right? That's, I think, what my wife would say. One of us works, right? I've never really been fond of that description. Investigative journalist. When asked what I suppose I would say, and I was to nail it down, am I a bank manager or an engine driver or an investigative journalist, I would go for the third. But I always think that it's a misnomer in the sense that everyone in this business, in the journalist business, should, in theory, try to dig beyond the grass that you can see and find out what's underneath. I totally get that. That is what we do, and that's what we've done in our career together. Yes. So having a look at your back catalog of books, 9 11, Pearl Harbor, Richard Nixon and Madeleine McCann, there's some high pressure topics in there. Do you ever find the difficulty and the emotion and the pressure of writing with quite inflammatory topics? Ever? Do the lines kind of get crossed with the relationship at all? Does that ever kind of come in? Or are you able to kind of mediate those pretty effectively? As a thoroughly cowed husband and co author, I will leave Robin to answer that on a serious note. Always the one to interject a serious note here. You know, frankly, we're incredibly lucky to be able to do the kind of work we do. You know, what a privilege to be able to explore some of the most important cultural and historical moments the last century and try to bring your own little bit of extra information into that to try to write that story. Well, sure, there's pressure, and we don't always agree, but I think the reason we have found that we're able to work together well is that we have sometimes we have slightly different strengths, but we're both incredibly relentless when it comes to the digging. And, you know, we really are. You know, if one isn't pushing, the other one is. And I think so. We have a real simpatico in that way. But also, I think each of us respects the other's talent. You know, Tony has an extraordinary ability to make the complex, simple, you know, to drive what we call a coach and horses through a knotty problem and make it possible for readers to understand something in a really, you know, basic but interesting way. And I think, you know, I'M pretty good at, you know, getting the big picture of things and, you know, delivering, you know, to the, to the project, all the nuts and bolts so that we can do that, so that we can have that material to base the story on. You know, I think Robin's been talking rather as though she said we don't really clash on things. Well, quite often we say, no, that's not right. No, it's not right. Because look, this is what I was digging up or this is of the X hundred interviews we'd done on the subject. Do you remember that? So and so said this. So we have to think about that. And the important thing is that we're playing mental ping pong and it's a terrific asset, actually. I have a friend and sometime colleague in the United States who already done one book about that seemingly eternal story, the assassination of President Kennedy in 1963. And having done one book which was a success and quite a serious book, not just one of those books, one more of those books about the Kennedy assassination, he launched into the research for a second. He has been on that now, by my most recent count, for about 25 years, possibly more on his own. And I think that's fatal for him. I've got a feeling he's going to die without the book having been published. But what he lacks is what we do have, which is someone to play intellectual ping pong with to say, I've just written these couple of paragraphs. What do y ...
#
# --- FULL TEXT (first 1000 chars) ---
# Ladies and gentlemen, welcome back. I am joined by Robin Swan and Anthony Summers. You may recognize them from the most recent Netflix series on the disappearance of Madeleine McCann. Guys, welcome to the show. Thank you very much. So you are investigative journalists, but you're also married and you've been working together for about 30 years, is that right? That's, I think, what my wife would say. One of us works, right? I've never really been fond of that description. Investigative journalist. When asked what I suppose I would say, and I was to nail it down, am I a bank manager or an engine driver or an investigative journalist, I would go for the third. But I always think that it's a misnomer in the sense that everyone in this business, in the journalist business, should, in theory, try to dig beyond the grass that you can see and find out what's underneath. I totally get that. That is what we do, and that's what we've done in our career together. Yes. So having a look at your back...
