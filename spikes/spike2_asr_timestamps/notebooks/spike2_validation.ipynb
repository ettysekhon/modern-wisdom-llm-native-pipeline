# %%
from pathlib import Path

import pandas as pd

repo_root = (
    Path(__file__).resolve().parents[2] if "__file__" in globals() else Path.cwd().parents[2]
)
TRANSCRIPTS_DIR = repo_root / "data" / "transcripts"


episode_id = "a897ddc2-bc12-11ef-8d4c-c3a09f837a28"
parquet_file = TRANSCRIPTS_DIR / f"episode_id={episode_id}" / "part-00000.snappy.parquet"

df = pd.read_parquet(parquet_file)

print("Columns:", df.columns.tolist())
print("\nFirst 5 rows:")
display(df.head())

# Combine into a readable transcript preview
print("\nTranscript Preview:")
for _, row in df.head(10).iterrows():
    speaker = f"[{row.speaker}]" if "speaker" in df.columns and pd.notna(row.get("speaker")) else ""
    print(f"{speaker} ({row.start_ts:.1f}–{row.end_ts:.1f}s): {row.text}")

# Full text (joined)
full_text = " ".join(df["text"].astype(str).tolist())
print("\n--- FULL TEXT (first 1000 chars) ---")
print(full_text[:1000] + ("..." if len(full_text) > 1000 else ""))
# Out:
# Columns: ['segment_idx', 'start_ts', 'end_ts', 'text', 'asr_model', 'confidence']
#
# First 5 rows:
#    segment_idx  start_ts  end_ts  \
# 0            0      0.32   15.40
# 1            1     15.40   18.00
# 2            2     18.00   25.36
# 3            3     25.92   28.48
# 4            4     28.88   29.60
#
#                                                 text   asr_model  confidence
# 0  The stuff that I've been focusing on over the ...  assemblyai     0.97322
# 1    well being and focus more on individual change.  assemblyai     0.97322
# 2  What do I need to do to change my life to make...  assemblyai     0.97322
# 3    Not that I survive, but that I actually thrive.  assemblyai     0.97322
# 4                                          And it's.  assemblyai     0.97322
# Transcript Preview:
#  (0.3–15.4s): The stuff that I've been focusing on over the last couple of years is making my audience, my clients, aware of the changes that are happening and having them try and disassociate from political change as a way to improve our lives and improve our
#  (15.4–18.0s): well being and focus more on individual change.
#  (18.0–25.4s): What do I need to do to change my life to make sure that over the next 20 years I prosper, I thrive?
#  (25.9–28.5s): Not that I survive, but that I actually thrive.
#  (28.9–29.6s): And it's.
#  (29.9–35.9s): I mean, it's a full time job just going through all that because we want to be focused on the stuff that doesn't matter.
#  (36.2–41.4s): We love focusing on the noise, but the noise doesn't make you any money.
#  (41.4–42.6s): The noise doesn't protect you.
#  (42.6–46.4s): The noise just distracts you, keeps you dependent and apathetic.
#  (51.0–53.3s): Jason Stapleton in the building.
#
# --- FULL TEXT (first 1000 chars) ---
# The stuff that I've been focusing on over the last couple of years is making my audience, my clients, aware of the changes that are happening and having them try and disassociate from political change as a way to improve our lives and improve our well being and focus more on individual change. What do I need to do to change my life to make sure that over the next 20 years I prosper, I thrive? Not that I survive, but that I actually thrive. And it's. I mean, it's a full time job just going through all that because we want to be focused on the stuff that doesn't matter. We love focusing on the noise, but the noise doesn't make you any money. The noise doesn't protect you. The noise just distracts you, keeps you dependent and apathetic. Jason Stapleton in the building. How are you doing, man? I'm doing well, brother. Thank you for having me on your show. Thank you for being here, dude. What's been going on, what you've been doing today? Well, today I've been doing a lot of. It's so funny ...
