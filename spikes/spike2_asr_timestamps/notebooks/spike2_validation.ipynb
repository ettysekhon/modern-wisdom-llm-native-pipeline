# %%
from pathlib import Path

import pandas as pd

repo_root = (
    Path(__file__).resolve().parents[2] if "__file__" in globals() else Path.cwd().parents[2]
)
TRANSCRIPTS_DIR = repo_root / "data" / "transcripts"


episode_id = "949b411c-bc1a-11ef-80c2-e386978dcc9f"
parquet_file = TRANSCRIPTS_DIR / f"episode_id={episode_id}" / "part-00000.snappy.parquet"

df = pd.read_parquet(parquet_file)

print("Columns:", df.columns.tolist())
print("\nFirst 5 rows:")
display(df.head())

# Combine into a readable transcript preview
print("\nTranscript Preview:")
for _, row in df.head(10).iterrows():
    speaker = f"[{row.speaker}]" if "speaker" in df.columns and pd.notna(row.get("speaker")) else ""
    print(f"{speaker} ({row.start_ts:.1f}–{row.end_ts:.1f}s): {row.text}")

# Full text (joined)
full_text = " ".join(df["text"].astype(str).tolist())
print("\n--- FULL TEXT (first 1000 chars) ---")
print(full_text[:1000] + ("..." if len(full_text) > 1000 else ""))
# Out:
# Columns: ['segment_idx', 'start_ts', 'end_ts', 'text', 'asr_model', 'confidence']
#
# First 5 rows:
#    segment_idx  start_ts  end_ts  \
# 0            0      0.48    2.24
# 1            1      2.24    3.52
# 2            2      7.92    9.92
# 3            3      9.92   12.44
# 4            4     12.44   14.88
#
#                                                 text   asr_model  confidence
# 0          How did you get into neighborhood design?  assemblyai    0.977078
# 1                                   Beef on Twitter.  assemblyai    0.977078
# 2            So, I mean, somebody shared a photo of.  assemblyai    0.977078
# 3  It was like an aerial photo of some neighborho...  assemblyai    0.977078
# 4                  And they were like, how would it.  assemblyai    0.977078
# Transcript Preview:
#  (0.5–2.2s): How did you get into neighborhood design?
#  (2.2–3.5s): Beef on Twitter.
#  (7.9–9.9s): So, I mean, somebody shared a photo of.
#  (9.9–12.4s): It was like an aerial photo of some neighborhood in Phoenix.
#  (12.4–14.9s): And they were like, how would it.
#  (14.9–18.2s): I forget what exactly was like, how would any human ever want to live here?
#  (18.7–22.6s): I was like, I mean, it looks like kind of a nice neighborhood.
#  (22.6–24.5s): Like, people have pools in their backyard.
#  (25.4–28.2s): It doesn't have like a big highway cutting through it or anything.
#  (29.3–30.5s): I street viewed the neighborhood.
#
# --- FULL TEXT (first 1000 chars) ---
# How did you get into neighborhood design? Beef on Twitter. So, I mean, somebody shared a photo of. It was like an aerial photo of some neighborhood in Phoenix. And they were like, how would it. I forget what exactly was like, how would any human ever want to live here? I was like, I mean, it looks like kind of a nice neighborhood. Like, people have pools in their backyard. It doesn't have like a big highway cutting through it or anything. I street viewed the neighborhood. There's a bunch of parks in the neighborhood. Like, there's in street view, you can see kids playing in the parks. Like, clearly people enjoy this neighborhood. I also looked up like the Zillow on it. Like houses in this, in this neighborhood, or like people clearly want to live here from the prices they're paying. So I said, like, you know, I don't know, it looks like a nice neighborhood. Like, it looks. It looks pretty nice to me. And the thing that really set people off is I said it looked relatively walkable. And ...
