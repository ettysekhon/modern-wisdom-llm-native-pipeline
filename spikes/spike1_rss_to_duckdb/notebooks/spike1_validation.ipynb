# %%
from pathlib import Path

import duckdb
from IPython.display import display

repo_root = (
    Path(__file__).resolve().parents[2] if "__file__" in globals() else Path.cwd().parents[2]
)
db_path = repo_root/"data"/"duckdb"/"modern_wisdom.duckdb"

con = duckdb.connect(str(db_path), read_only=True)

recent = con.execute("""
    SELECT id, title, publish_date
    FROM mw.episodes
    ORDER BY publish_date DESC
    LIMIT 10
""").df()

per_year = con.execute("""
    SELECT strftime(CAST(publish_date AS DATE), '%Y') AS year,
           COUNT(*) AS count
    FROM mw.episodes
    WHERE publish_date IS NOT NULL
    GROUP BY year
    ORDER BY year
""").df()

display(recent)
per_year
# Out:
#                                      id  \
# 0  d57ba53e-bc1d-11ef-b308-3344b2ed6afa
# 1  b1ff2720-bc1d-11ef-822a-6750b8f433e6
# 2  9f60bbe2-bc1d-11ef-ac41-eb8ac7e5cff7
# 3  88c47162-bc1d-11ef-8c25-7f53cf76b573
# 4  7365f7aa-bc1d-11ef-b612-97f0e69f29f8
# 5  5dd52a78-bc1d-11ef-849d-ab70e6a524cf
# 6  457ac654-bc1d-11ef-8149-8b4bec991564
# 7  2e9f02ce-bc1d-11ef-9a33-37ce1a17ccdc
# 8  92835442-bc23-11ef-a274-b7c3cce75098
# 9  044e0916-bc1d-11ef-b423-6b502900e2ec
#
#                                                title publish_date
# 0  #993 - Katie Herzog - A Controversial New Cure...   2025-09-13
# 1  #992 - Dr Sarah Hill - The Period Brain: How H...   2025-09-11
# 2  #991 - Dr John Delony - The Blueprint for Bett...   2025-09-08
# 3  #990 - Dr Tara Swart - How to Use Your Intuiti...   2025-09-06
# 4  #989 - James Kimmel Jr. - Why Violence & Reven...   2025-09-04
# 5  #988 - Dr Rahul Jandial - Brain Surgeon: Insid...   2025-09-01
# 6  #987 - Dr Lisa Feldman Barrett - The New Scien...   2025-08-30
# 7  #986 - Esther Perel - How Love Dies: The Psych...   2025-08-28
# 8  #985 - Dr David Spiegel - Hypnosis, Brain Hack...   2025-08-25
# 9  #984 - Coltan Scrivner - Why We’re Drawn to De...   2025-08-23
#    year  count
# 0  2018     43
# 1  2019     85
# 2  2020    133
# 3  2021    153
# 4  2022    154
# 5  2023    155
# 6  2024    158
# 7  2025    110
